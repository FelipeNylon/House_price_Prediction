# %%
#imports 
import pandas as pd 
from sklearn import linear_model as lm 
import numpy as np

# %%
#loading data
data = pd.read_csv(r"C:\Users\Lipe Marlon\Documents\House_Rockets\kc_house_data.csv")

data[0:9]
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# ...

# %%
#data preparation 
x_train = data.drop(['price', 'date'], axis=1)
y_train = data['price'].copy()
display(x_train.head())
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
#model training 

model_lr = lm.LinearRegression()

model_lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model_lr.predict(x_train)
pred[0:100]
# Out:
# array([ 205766.26460962,  731219.64982987,  379097.88265418,
#         457424.13432529,  444789.05471811, 1451676.80046281,
#         277965.14285807,  135261.77208383,  329843.81624395,
#         250731.2505036 ,  870212.88141874,  437789.72121285,
#         600311.43498101,  316903.13655575,  611557.85739091,
#         944453.29692623,  456573.68626293,  539004.69481031,
#         335024.25629832,  210585.07434927,  466088.95603629,
#        1116489.11078675,  330386.45026626,  130784.11743752,
#         545423.99906282,  310538.26026988,  802018.13764891,
#         651875.20382829,  457699.206153  ,  650018.45024566,
#         541202.92170083,  332196.71884794,  655096.04733202,
#         555240.33756537,  319817.174744  ,  804301.3547089 ,
#         201145.17195308,  861533.54324498,  103130.75983528,
#         585745.32147527,  664511.50307343,  742662.60624429,
#         863042.39845927,  508391.02023419,  153710.08047338,
# ...

# %%
#perfomance metrics
datacopy = data.copy()

# %%
datacopy['prediction'] = pred

# %%
datacopy[['id', 'price', 'prediction', 'error', 'error_abs','error_percentual','error_percentual_abs']][0:9]
# Out:
#            id      price    prediction          error      error_abs  \
# 0  7129300520   221900.0  2.057663e+05   16133.735390   16133.735390
# 1  6414100192   538000.0  7.312196e+05 -193219.649830  193219.649830
# 2  5631500400   180000.0  3.790979e+05 -199097.882654  199097.882654
# 3  2487200875   604000.0  4.574241e+05  146575.865675  146575.865675
# 4  1954400510   510000.0  4.447891e+05   65210.945282   65210.945282
# 5  7237550310  1225000.0  1.451677e+06 -226676.800463  226676.800463
# 6  1321400060   257500.0  2.779651e+05  -20465.142858   20465.142858
# 7  2008000270   291850.0  1.352618e+05  156588.227916  156588.227916
# 8  2414600126   229500.0  3.298438e+05 -100343.816244  100343.816244
#
#    error_percentual  error_percentual_abs
# 0          0.072707              0.072707
# 1         -0.359144              0.359144
# 2         -1.106099              1.106099
# 3          0.242675              0.242675
# 4          0.127865              0.127865
# ...

# %%
#calculando o erro da regressão linear 

datacopy['error'] = datacopy['price'] - datacopy['prediction']
datacopy['error_abs'] = np.abs(datacopy['error'])
datacopy['error_percentual'] = ((datacopy['price']-datacopy['prediction'])/datacopy['price'])
datacopy['error_percentual_abs'] = np.abs(datacopy['error_percentual'])

# %%
np.sum(datacopy['error_abs']) / len(datacopy['error_abs'])
# Out:
# 125921.54419397873

# %%
#tirando a média de error das predições, 25% de média de erro da regressão 
np.mean(datacopy['error_percentual_abs'])
# Out:
# 0.2558051253618486
